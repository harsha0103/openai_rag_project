# %% [markdown]
# # Openai Models

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()
key=os.getenv('OPENAI_API_KEY')
llm=ChatOpenAI( model='gpt-4o',api_key=key)
question=input("ask a question")
response=llm.invoke(question)
print(response.content)
# Out:
# I'm just a computer program, so I don't have feelings, but I'm here and ready to help you! How can I assist you today?

# %% [markdown]
# # gemma Model

# %%
from langchain_ollama import ChatOllama

ollama_llm=ChatOllama(model='mistral')
ollama_question=input("ask a question to ollama")
response=ollama_llm.invoke(ollama_question)
print(response.content)
# Out:
#  I'm an AI, so I don't have feelings, but I'm here to help answer your questions! How can I assist you today?

# %% [markdown]
# # streamlit

# %%
import streamlit as st

st.title("ask me anything")

question=st.text_input("enter a question")

if question:
    response=llm.invoke(question)
    st.write(response.content)
# Out:
# 2026-08-01 10:28:12.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-01 10:28:12.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
